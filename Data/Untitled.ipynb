# %%
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv('results.csv')

# %%
data
# Out:
#        Unnamed: 0  season  round  circuit_id             driver date_of_birth  \
# 0               0    1990      1     phoenix              senna    1960-03-21
# 1               1    1990      1     phoenix              alesi    1964-06-11
# 2               2    1990      1     phoenix            boutsen    1957-07-13
# 3               3    1990      1     phoenix             piquet    1952-08-17
# 4               4    1990      1     phoenix             modena    1963-05-12
# ...           ...     ...    ...         ...                ...           ...
# 12392       12392    2020     17  yas_marina         giovinazzi    1993-12-14
# 12393       12393    2020     17  yas_marina             latifi    1995-06-29
# 12394       12394    2020     17  yas_marina    kevin_magnussen    1992-10-05
# 12395       12395    2020     17  yas_marina  pietro_fittipaldi    1996-06-25
# 12396       12396    2020     17  yas_marina              perez    1990-01-26
#
# ...

# %%
number_one_q=data['grid']==1
number_one_podium=data['podium']==1

# %%
filtered_data_q=data[number_one]
filtered_data_podium=data[number_one_podium]

# %%
filtered_data_podium
# Out:
#        Unnamed: 0  season  round  circuit_id          driver date_of_birth  \
# 0               0    1990      1     phoenix           senna    1960-03-21
# 30             30    1990      2  interlagos           prost    1955-02-24
# 60             60    1990      3       imola         patrese    1954-04-17
# 90             90    1990      4      monaco           senna    1960-03-21
# 120           120    1990      5  villeneuve           senna    1960-03-21
# ...           ...     ...    ...         ...             ...           ...
# 12297       12297    2020     13       imola        hamilton    1985-01-07
# 12317       12317    2020     14    istanbul        hamilton    1985-01-07
# 12337       12337    2020     15     bahrain        hamilton    1985-01-07
# 12357       12357    2020     16     bahrain           perez    1990-01-26
# 12377       12377    2020     17  yas_marina  max_verstappen    1997-09-30
#
# ...

# %%
sns.relplot(x="grid", y="podium", data=filtered_data_q) #On obtient qqc qui paraît totalement random ce qui n'est pas trop logique a priori
